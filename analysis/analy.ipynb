# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import numpy as np

# %%
conn = sqlite3.connect('../database/dados_bot.db')
df = pd.read_sql_query('SELECT * from execucao_do_bot', conn)
df.head()
# Out:
#    id        data_execucao             data_fim  duracao_minutos  \
# 0   1    1752702414.063966  16-07-2025 18:46:59         0.083342
# 1   2  16-07-2025 18:47:56  16-07-2025 18:48:01         0.083341
# 2   3    1752702556.372765  16-07-2025 18:49:21         0.083000
# 3   4    1752702574.085952  16-07-2025 18:49:39         0.080000
# 4   5    1752702594.884772  16-07-2025 18:50:54         1.000000
#
#    qtd_reparadores  ferramentas_concertadas  relatorio_guardar
# 0                0                        0                  1
# 1                0                        0                  0
# 2                0                        0                  1
# 3                0                        0                  1
# 4                0                        0                  1

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       19 non-null     int64
#  1   data_execucao            19 non-null     object
#  2   data_fim                 19 non-null     object
#  3   duracao_minutos          19 non-null     float64
#  4   qtd_reparadores          19 non-null     int64
#  5   ferramentas_concertadas  19 non-null     int64
#  6   relatorio_guardar        19 non-null     int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 1.2+ KB
#               id  duracao_minutos  qtd_reparadores  ferramentas_concertadas  \
# count  19.000000        19.000000        19.000000                19.000000
# mean   10.000000        38.317878         9.631579                 0.736842
# std     5.627314        33.418288         8.877002                 0.733493
# ...

# %%
df.hist(bins=25, figsize=(15,13))
df.tight_layout=True
plt.show()
